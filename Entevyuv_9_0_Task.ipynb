# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeja145/Job-Insights-Analyzing-Employment-Trends-and-Skills-in-Data-Science/blob/main/Entevyuv_9_0_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Project flow
#
#
# 1.   *Understand the data*
# 2.   *Clean the data*
# 3. *Visualize the data*
# 4. *FInd out answers to given Problems*

# %% [markdown]
# ## Knowing the data

# %% [markdown]
# ### Get the data

# %%
df=pd.read_csv('Uncleaned_DS_jobs.csv')

# %%
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description             Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst\n3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech\n4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group\n3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON\n3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions\n2.9
#
#         Location            Headquarters                     Size  Founded  \
# ...

# %%
df.shape
# Out:
# (672, 14)

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description             Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst\n3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech\n4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group\n3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON\n3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions\n2.9
#
#         Location            Headquarters                     Size  Founded  \
# 0   New York, NY            New York, NY   1001 to 5000 employees     1993
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          672 non-null    object
#  1   Salary Estimate    672 non-null    object
#  2   Job Description    672 non-null    object
#  3   Company Name       672 non-null    object
#  4   Location           672 non-null    object
#  5   Headquarters       672 non-null    object
#  6   Size               672 non-null    object
#  7   Founded            672 non-null    int64
#  8   Type of ownership  672 non-null    object
#  9   Industry           672 non-null    object
#  10  Sector             672 non-null    object
#  11  Revenue            672 non-null    object
#  12  Competitors        672 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 68.4+ KB

# %%
len(df['Job Title'].value_counts())
# Out:
# 172

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                            337
# Data Engineer                                              26
# Senior Data Scientist                                      19
# Machine Learning Engineer                                  16
# Data Analyst                                               12
#                                                          ...
# Data Science Instructor                                     1
# Business Data Analyst                                       1
# Purification Scientist                                      1
# Data Engineer, Enterprise Analytics                         1
# AI/ML - Machine Learning Scientist, Siri Understanding      1
# Name: Job Title, Length: 172, dtype: int64

# %%
df['Salary Estimate'].value_counts()
# Out:
# $79K-$131K (Glassdoor est.)     32
# $99K-$132K (Glassdoor est.)     32
# $75K-$131K (Glassdoor est.)     32
# $137K-$171K (Glassdoor est.)    30
# $90K-$109K (Glassdoor est.)     30
# $56K-$97K (Glassdoor est.)      22
# $79K-$106K (Glassdoor est.)     22
# $90K-$124K (Glassdoor est.)     22
# $110K-$163K (Glassdoor est.)    21
# $92K-$155K (Glassdoor est.)     21
# $138K-$158K (Glassdoor est.)    21
# $128K-$201K (Glassdoor est.)    21
# $212K-$331K (Glassdoor est.)    21
# $95K-$119K (Glassdoor est.)     21
# $69K-$116K (Glassdoor est.)     21
# $124K-$198K (Glassdoor est.)    21
# $112K-$116K (Glassdoor est.)    21
# $122K-$146K (Glassdoor est.)    21
# $91K-$150K (Glassdoor est.)     21
# $101K-$165K (Glassdoor est.)    21
# $79K-$147K (Glassdoor est.)     20
# $31K-$56K (Glassdoor est.)      20
# $145K-$225K(Employer est.)      20
# $141K-$225K (Glassdoor est.)    20
# $66K-$112K (Glassdoor est.)     20
# $80K-$132K (Glassdoor est.)     20
# $87K-$141K (Glassdoor est.)     20
# ...

# %%
len(df['Salary Estimate'].value_counts())
# Out:
# 30

# %%
len(df['Job Description'].value_counts())
# Out:
# 489

# %%
df['Company Name'].value_counts()
# Out:
# Hatch Data Inc                      12
# Maxar Technologies\n3.5             12
# Tempus Labs\n3.3                    11
# AstraZeneca\n4.0                    10
# Klaviyo\n4.8                         8
#                                     ..
# Better Hire\n4.0                     1
# Rincon Research Corporation\n4.2     1
# Descript\n4.3                        1
# Trace Data\n3.9                      1
# ChaTeck Incorporated\n5.0            1
# Name: Company Name, Length: 432, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# San Francisco, CA    69
# New York, NY         50
# Washington, DC       26
# Boston, MA           24
# Chicago, IL          22
#                      ..
# Oshkosh, WI           1
# Culver City, CA       1
# Lake Oswego, OR       1
# New Orleans, LA       1
# Irwindale, CA         1
# Name: Location, Length: 207, dtype: int64

# %%
df['Headquarters'].value_counts()
# Out:
# New York, NY         33
# -1                   31
# San Francisco, CA    31
# Chicago, IL          23
# Boston, MA           19
#                      ..
# Irving, TX            1
# Scottsdale, AZ        1
# Greensboro, NC        1
# Newark, CA            1
# Fort Lee, NJ          1
# Name: Headquarters, Length: 229, dtype: int64

# %%
df['Size'].value_counts()
# Out:
# 51 to 200 employees        135
# 1001 to 5000 employees     104
# 1 to 50 employees           86
# 201 to 500 employees        85
# 10000+ employees            80
# 501 to 1000 employees       77
# 5001 to 10000 employees     61
# -1                          27
# Unknown                     17
# Name: Size, dtype: int64

# %%
df['Founded'].value_counts()
# Out:
# -1       118
#  2012     34
#  2011     25
#  2015     22
#  2010     22
#         ...
#  1820      1
#  1952      1
#  1959      1
#  1894      1
#  1962      1
# Name: Founded, Length: 103, dtype: int64

# %%
df['Type of ownership'].value_counts()
# Out:
# Company - Private                 397
# Company - Public                  153
# Nonprofit Organization             36
# Subsidiary or Business Segment     28
# -1                                 27
# Government                         10
# Other Organization                  5
# Private Practice / Firm             4
# Unknown                             4
# College / University                3
# Self-employed                       2
# Contract                            2
# Hospital                            1
# Name: Type of ownership, dtype: int64

# %%
df['Industry'].value_counts()
# Out:
# -1                                          71
# Biotech & Pharmaceuticals                   66
# IT Services                                 61
# Computer Hardware & Software                57
# Aerospace & Defense                         46
# Enterprise Software & Network Solutions     43
# Consulting                                  38
# Staffing & Outsourcing                      36
# Insurance Carriers                          28
# Internet                                    27
# Advertising & Marketing                     23
# Health Care Services & Hospitals            21
# Research & Development                      17
# Federal Agencies                            16
# Investment Banking & Asset Management       13
# Banks & Credit Unions                        8
# Lending                                      8
# Energy                                       5
# Consumer Products Manufacturing              5
# Telecommunications Services                  5
# ...

# %%
len(df['Industry'].value_counts())
# Out:
# 58

# %%
df['Sector'].value_counts()
# Out:
# Information Technology                188
# Business Services                     120
# -1                                     71
# Biotech & Pharmaceuticals              66
# Aerospace & Defense                    46
# Finance                                33
# Insurance                              32
# Manufacturing                          23
# Health Care                            21
# Government                             17
# Oil, Gas, Energy & Utilities           10
# Retail                                  7
# Telecommunications                      7
# Transportation & Logistics              6
# Media                                   5
# Real Estate                             3
# Travel & Tourism                        3
# Agriculture & Forestry                  3
# Education                               3
# Accounting & Legal                      3
# Construction, Repair & Maintenance      2
# Consumer Services                       2
# ...

# %%
len(df['Sector'].value_counts())
# Out:
# 23

# %%
df['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            213
# $100 to $500 million (USD)           94
# $10+ billion (USD)                   63
# $2 to $5 billion (USD)               45
# $10 to $25 million (USD)             41
# $1 to $2 billion (USD)               36
# $25 to $50 million (USD)             36
# $50 to $100 million (USD)            31
# $1 to $5 million (USD)               31
# -1                                   27
# $500 million to $1 billion (USD)     19
# $5 to $10 million (USD)              14
# Less than $1 million (USD)           14
# $5 to $10 billion (USD)               8
# Name: Revenue, dtype: int64

# %%
df['Competitors'].value_counts()
# Out:
# -1                                                                501
# Roche, GlaxoSmithKline, Novartis                                   10
# Los Alamos National Laboratory, Battelle, SRI International         6
# Leidos, CACI International, Booz Allen Hamilton                     6
# MIT Lincoln Laboratory, Lockheed Martin, Northrop Grumman           3
#                                                                  ...
# Pfizer, GlaxoSmithKline                                             1
# Square, Amazon, Apple                                               1
# Lumentum Operations, Keysight Technologies, O-Net Technologies      1
# Munich Re, Hannover RE, SCOR                                        1
# Genomic Health, Myriad Genetics, The Broad Institute                1
# Name: Competitors, Length: 108, dtype: int64

# %% [markdown]
# ---
#
#
# *   Data contains 13 columns and 672 rows
# *   The data is about dataset of data science jobs posted in job portals
# *   Each of these columns explain details regarding companies that are recruting for data science positions
#
#
# ---
#
#
# *   there are 172 different job titles, top most job title is Data Scientist.
# *   there are 30 ranges in job salaries, each salary is equally distributed in the distributed.
# *   out of 672 job post, there are 489 unique job descriptions.
#
#
# ---
#
#
# *   there are 432 different companies who posted oppurtunities.
# *   there are 207 different locations for jobs.
# *   there are some value which are just -1 for Headquarters.
#
#
# ---
#
#
# *   there are unknown values in size of the company working.
# *   there are also missing values in Founded year.
# *   there are missing values in type of ownership.
#
#
# ---
#
# * there are 58 different industries that companies are offering jobs, there are missing values too in this column.
# * there are 23 different sectors.
#
#
# ---
#
# * revenue ranges from 1 million dollars to 10 billion dollars in different ranges.
# * competitors for the company differs from one to one, but most companies are
# having null values as their competitors.

# %% [markdown]
# ##cleansing the data

# %% [markdown]
# ### Job title

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                            337
# Data Engineer                                              26
# Senior Data Scientist                                      19
# Machine Learning Engineer                                  16
# Data Analyst                                               12
#                                                          ...
# Data Science Instructor                                     1
# Business Data Analyst                                       1
# Purification Scientist                                      1
# Data Engineer, Enterprise Analytics                         1
# AI/ML - Machine Learning Scientist, Siri Understanding      1
# Name: Job Title, Length: 172, dtype: int64

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data science' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'machine learning engineer'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    elif 'scientist' in title.lower():
        return 'other scientist'
    elif 'data modeler' in title.lower():
        return 'data modeler'
    elif 'data' and 'anal' in title.lower():
        return 'data analytics'
    else:
        return 'na'  #not applicable

# %%
df['job_titles_simply']=df['Job Title'].apply(title_simplifier)

# %%
df['job_titles_simply'].value_counts()
# Out:
# data scientist               474
# analyst                       54
# data engineer                 46
# other scientist               45
# machine learning engineer     35
# data modeler                   5
# data analytics                 4
# manager                        4
# na                             3
# director                       2
# Name: job_titles_simply, dtype: int64

# %%
def seniority(title):
  if 's.sr' in title.lower() or 's. sr' in title.lower() or 's sr' in title.lower() or 'ssr' in title.lower() or 's. senior' in title.lower() or 'semi or' in title.lower() or 'middle' in title.lower() or 'mid' in title.lower():
      return 'ssr'
  elif 'jr' in title.lower() or 'junior' in title.lower():
      return 'jr'
  elif 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
      return 'sr'
  else:
      return 'na'

# %%
print(seniority('senior data scientist'))
# Out:
# sr

# %%
df['seniority_by_title']=df['Job Title'].apply(seniority)

# %%
df['seniority_by_title'].value_counts()
# Out:
# na     575
# sr      94
# jr       2
# ssr      1
# Name: seniority_by_title, dtype: int64

# %% [markdown]
# * as there are many different job titles, we might want to check if there is any common things between them, making job titles simplified.
# * After simplification, the positions of jobs range from junior to director level, which makes huge difference in pay.

# %% [markdown]
# ### Salary Estimate

# %%
df['Salary Estimate'].dtype
# Out:
# dtype('O')

# %%
df['Salary Estimate'][1]
# Out:
# '$137K-$171K (Glassdoor est.)'

# %%
# we can remove string glassdoor recommended from the values.
import re
for i in range(0,df.shape[0]):
  salary=df['Salary Estimate'][i]
  df['Salary Estimate'][i]=re.sub("\(.*?\)","",salary)
  df['Salary Estimate'][i]=df['Salary Estimate'][i].strip()

# %%
df['Salary Estimate'][1]
# Out:
# '$137K-$171K'

# %%
salary=df['Salary Estimate'].apply(lambda x:x.replace('K',"").replace('$',""))              # erasing $ and K from the salary

# %%
df['min_salary']=salary.apply(lambda x:int(x.split('-')[0]))

# %%
df['max_salary']=salary.apply(lambda x:int(x.split('-')[1]))

# %%
df['avg_salary']=(df['min_salary']+df['max_salary'])/2

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist     $137K-$171K
# 1     Data Scientist     $137K-$171K
# 2     Data Scientist     $137K-$171K
# 3     Data Scientist     $137K-$171K
# 4     Data Scientist     $137K-$171K
#
#                                      Job Description             Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst\n3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech\n4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group\n3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON\n3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions\n2.9
#
#         Location            Headquarters                     Size  Founded  \
# 0   New York, NY            New York, NY   1001 to 5000 employees     1993
# 1  Chantilly, VA             Herndon, VA  5001 to 10000 employees     1968
# ...

# %% [markdown]
# *🙂 💰 💰   Salary Estimate*
#
#
# *   There are no unknown values in salary estimate column
# *   To calculate the minimum and maximum salaries, they are split '-'  and kept in different columns.
# *   Average salary is calculated by taking average of minimum and maximum salaries.

# %% [markdown]
# ### Job description

# %%
df['Job Description'][1]
# Out:
# "Secure our Nation, Ignite your Future\n\nJoin the top Information Technology and Analytic professionals in the industry to make invaluable contributions to our national security on a daily basis. In this innovative, self-contained, Big Data environment, the ManTech team is responsible for everything from infrastructure, to application development, to data science, to advanced analytics and beyond. The team is diverse, the questions are thought-provoking, and the opportunities for growth and advancement are numerous\n\nThe successful candidate will possess a diverse range of data-focused skills and experience, both technical and analytical. They will have a strong desire and capability for problem solving, data analysis and troubleshooting, analytical thinking, and experimentation.\n\nDuties, Tasks & Responsibilities\nWorking with large, complex, and disparate data sets\nDesigning and implementing innovative ways to analyze and exploit the Sponsors data holdings\nResearching and repo
# ...

# %% [markdown]
# Here are different skills that must be possessed by one or the other job titles.
#
#
# ---
#
# Python	R	Spark	AWS	Excel	SQL
# SAS	d3.js	Julia	Jupyter	Keras	MatLab
# MatPlotLib	PyTorch	Scikit-Learn	Tensor Flow	Weka	Selenium
# Hadoop	Tableau	Power BI	BigML	RapidMiner	Apache Flink
# DataRobot	SAP Hana	Mongo DB	Trifacta	MiniTab	Kafka
# MicroStrategy	Google Analytics	SPSS
#
# resource:
# https://www.knowledgehut.com/blog/data-science/data-science-tools
#
# https://www.techtarget.com/searchbusinessanalytics/feature/15-data-science-tools-to-consider-using

# %%
df['python_yn']  = df['Job Description'].apply(lambda x: 1 if 'py' in x.lower() else 0)
    # the _yn in the name means that what I'm doing is split by yes or no there is "python" in the description.
df.python_yn.value_counts()
#r studio
    #If you say "hey, I know r and py" looks like " r " is the correct way to search it.
df['R_yn']  = df['Job Description'].apply(lambda x: 1 if ' r ' in x.lower() or 'r-studio' in x.lower() or ' r,' in x.lower() or ' r.' in x.lower() else 0)
df.R_yn.value_counts()
#spark
df['spark_yn']  = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df.spark_yn.value_counts()
#aws
df['aws_yn']  = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df.aws_yn.value_counts()
#excel
df['excel_yn']  = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df.excel_yn.value_counts()
#sql
df['sql_yn']  = df['Job Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0)
df.sql_yn.value_counts()
#sas 
df['sas_yn']  = df['Job Description'].apply(lambda x: 1 if (' sas ' in x.lower() or ' sas,' in x.lower() or ' sas.' in x.lower())  else 0)
df.sas_yn.value_counts()
#d3js
df['d3js_yn']  = df['Job Description'].apply(lambda x: 1 if 'd3' in x.lower() else 0)
df.d3js_yn.value_counts()
#julia
df['julia_yn']  = df['Job Description'].apply(lambda x: 1 if 'julia' in x.lower() else 0)
df.julia_yn.value_counts()
#jupyter
df['jupyter_yn']  = df['Job Description'].apply(lambda x: 1 if 'jupyter' in x.lower() else 0)
df.jupyter_yn.value_counts()
#keras
df['keras_yn']  = df['Job Description'].apply(lambda x: 1 if 'keras' in x.lower() else 0)
df.keras_yn.value_counts()
#matlab
df['matlab_yn']  = df['Job Description'].apply(lambda x: 1 if 'matlab' in x.lower() else 0)
df.matlab_yn.value_counts()
#matplotlib
df['matplotlib_yn']  = df['Job Description'].apply(lambda x: 1 if 'matplotlib' in x.lower() else 0)
df.matplotlib_yn.value_counts()
#pytorch
df['pytorch_yn']  = df['Job Description'].apply(lambda x: 1 if 'pytorch' in x.lower() else 0)
df.pytorch_yn.value_counts()
#scikit-learn
df['scikit_yn']  = df['Job Description'].apply(lambda x: 1 if 'scikit' in x.lower() else 0)
df.scikit_yn.value_counts()
#tensor
df['tensor_yn']  = df['Job Description'].apply(lambda x: 1 if 'tensor' in x.lower() else 0)
df.tensor_yn.value_counts()
#weka
df['weka_yn']  = df['Job Description'].apply(lambda x: 1 if 'weka' in x.lower() else 0)
df.weka_yn.value_counts()
#selenium
df['selenium_yn']  = df['Job Description'].apply(lambda x: 1 if 'selenium' in x.lower() else 0)
df.selenium_yn.value_counts()
#hadoop
df['hadoop_yn']  = df['Job Description'].apply(lambda x: 1 if 'hadoop' in x.lower() else 0)
df.hadoop_yn.value_counts()
#tableau
df['tableau_yn']  = df['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)
df.tableau_yn.value_counts()
#power bi
df['bi_yn']  = df['Job Description'].apply(lambda x: 1 if ('power bi' in x.lower() or 'powerbi' in x.lower()) else 0)
df.bi_yn.value_counts()
#bigml
df['bigml_yn']  = df['Job Description'].apply(lambda x: 1 if 'bigml' in x.lower() else 0)
df.bigml_yn.value_counts()
#rapidminer
df['rapidminer_yn']  = df['Job Description'].apply(lambda x: 1 if 'rapidminer' in x.lower() else 0)
df.rapidminer_yn.value_counts()
#apache flink
df['flink_yn']  = df['Job Description'].apply(lambda x: 1 if 'flink' in x.lower() else 0)
df.flink_yn.value_counts()
#datarobot
df['datarobot_yn']  = df['Job Description'].apply(lambda x: 1 if 'datarobot' in x.lower() else 0)
df.datarobot_yn.value_counts()
#sap hana
df['hana_yn']  = df['Job Description'].apply(lambda x: 1 if 'hana' in x.lower() else 0)
df.hana_yn.value_counts()
#mongo db
df['mongo_yn']  = df['Job Description'].apply(lambda x: 1 if 'mongo' in x.lower() else 0)
df.mongo_yn.value_counts()
#trifacta
df['trifacta_yn']  = df['Job Description'].apply(lambda x: 1 if 'trifacta' in x.lower() else 0)
df.trifacta_yn.value_counts()
#minitab
df['minitab_yn']  = df['Job Description'].apply(lambda x: 1 if 'minitab' in x.lower() else 0)
df.minitab_yn.value_counts()
#kafka
df['kafka_yn']  = df['Job Description'].apply(lambda x: 1 if 'kafka' in x.lower() else 0)
df.kafka_yn.value_counts()
#microstrategy
df['microstrategy_yn']  = df['Job Description'].apply(lambda x: 1 if 'microstrategy' in x.lower() else 0)
df.microstrategy_yn.value_counts()
#google analytics
df['google_an_yn']  = df['Job Description'].apply(lambda x: 1 if 'google analytics' in x.lower() else 0)
df.google_an_yn.value_counts()
#Statistical Package for the Social Sciences
df['spss_yn']  = df['Job Description'].apply(lambda x: 1 if 'spss' in x.lower() else 0)
df.spss_yn.value_counts()
# Out:
# 0    659
# 1     13
# Name: spss_yn, dtype: int64

# %% [markdown]
# ### Degree

# %%
def education_credit(degree):
    if 'master' in degree.lower() or 'masters' in degree.lower() or "master's" in degree.lower():
        return 'M'
    elif 'phd' in degree.lower() or 'ph.d' in degree.lower():
        return 'P'
    else:
        return 'na'

# %%
df['Degree'] = df['Job Description'].apply(education_credit)
df.Degree.value_counts()
# Out:
# na    384
# M     176
# P     112
# Name: Degree, dtype: int64

# %% [markdown]
# 🖊 📚 📚
# 1.   Job description contains entire data about what company is seeking from candidates, on what technologies and fields they work, what skills are required.
#
# 2.   To get the academic qualifications from the description, we can list out required skills for different positions and check if they are present.

# %% [markdown]
# ### Company Name

# %%
df['Company Name'][0]
# Out:
# 'Healthfirst\n3.1'

# %%
df['Company Name'][3].split('\n')[1]
# Out:
# '3.5'

# %%
df['Company Name text']=df['Company Name'].apply(lambda x:x.split('\n')[0])

# %%
df['Rating']=df['Company Name'].apply(lambda x:x.split('\n')[-1])

# %% [markdown]
# ⭐ ⭐ ⭐ ⭐ ⭐
# 1. We got rating of the company included in the company name
# 2. seperating them with split '\n', we get the Company name and Rating.

# %% [markdown]
# ### Location

# %%
df['Location'].value_counts()
# Out:
# San Francisco, CA    69
# New York, NY         50
# Washington, DC       26
# Boston, MA           24
# Chicago, IL          22
#                      ..
# Oshkosh, WI           1
# Culver City, CA       1
# Lake Oswego, OR       1
# New Orleans, LA       1
# Irwindale, CA         1
# Name: Location, Length: 207, dtype: int64

# %%
df['Location'][0].split(',')[-1].strip()
# Out:
# 'NY'

# %%
df['Job_location']=df['Location'].apply(lambda x:x.split(',')[-1].strip())

# %%
df['Job_location'].value_counts()
# Out:
# CA               165
# VA                89
# MA                62
# NY                52
# MD                40
# IL                30
# DC                26
# TX                17
# WA                16
# OH                14
# PA                12
# MO                12
# United States     11
# NJ                10
# CO                10
# GA                 9
# NC                 9
# TN                 8
# FL                 8
# Remote             6
# OK                 6
# WI                 6
# IN                 5
# MI                 5
# AL                 4
# CT                 4
# MN                 4
# AZ                 4
# NE                 3
# UT                 3
# IA                 3
# RI                 2
# New Jersey         2
# SC                 2
# OR                 2
# Utah               2
# NH                 2
# MS                 1
# LA                 1
# KS                 1
# Texas              1
# DE                 1
# California         1
# ...

# %%
df['Job_location']=df['Job_location'].apply(lambda x:x.strip() if x!='New Jersey' else 'NJ' )
df['Job_location']=df['Job_location'].apply(lambda x:x.strip() if x!='California' else 'CA')
df['Job_location']=df['Job_location'].apply(lambda x:x.strip() if x!='Texas' else 'TX')
df['Job_location']=df['Job_location'].apply(lambda x:x.strip() if x!='Utah' else 'UT')
df['Job_location']=df['Job_location'].apply(lambda x:x.strip() if x!='United States' else 'US')

# %%
df['Job_location'].value_counts()
# Out:
# CA        166
# VA         89
# MA         62
# NY         52
# MD         40
# IL         30
# DC         26
# TX         18
# WA         16
# OH         14
# PA         12
# NJ         12
# MO         12
# US         11
# CO         10
# GA          9
# NC          9
# FL          8
# TN          8
# OK          6
# Remote      6
# WI          6
# UT          5
# MI          5
# IN          5
# CT          4
# MN          4
# AL          4
# AZ          4
# IA          3
# NE          3
# SC          2
# OR          2
# RI          2
# NH          2
# MS          1
# LA          1
# KS          1
# DE          1
# WV          1
# Name: Job_location, dtype: int64

# %%
df['same_state'] = df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis=1)

# %% [markdown]
# 1. there are different cities in each state which has offered job positions.
# 2. Instead of taking different cities, for simplifying we take different states, ignoring cities.
# 3. If Location and Headquarters are same, we give as 1 else 0.

# %% [markdown]
# ### Size

# %%
df['Size'].value_counts()
# Out:
# 51 to 200 employees        135
# 1001 to 5000 employees     104
# 1 to 50 employees           86
# 201 to 500 employees        85
# 10000+ employees            80
# 501 to 1000 employees       77
# 5001 to 10000 employees     61
# -1                          27
# Unknown                     17
# Name: Size, dtype: int64

# %%
len(df['Size']==-1)
# Out:
# 672

# %%
df["Size"] = df["Size"].apply(lambda x: x.lower().replace("employees",""))
df["Size"] = df["Size"].apply(lambda x: x.lower().replace(" to "," - "))

# %%
df['Size']=df['Size'].apply(lambda x:'na' if x.lower=='unknown' else ('na' if '-1' in x.lower() else x))

# %% [markdown]
# ⭕ ⚪ 🖥
#  we have unknown values and -1 as the value, we are considering both of them to be 'na' not a number.

# %% [markdown]
# ### Founded

# %%
len(df[df['Founded']==-1])/len(df)
# Out:
# 0.17559523809523808

# %%
df['Founded']=df['Founded'].apply(lambda x:'na' if x==-1 else x)

# %% [markdown]
# * there are 118 rows of missing values for year founded, which is 17% of total data.
# * If we remove them, we would lose important data.
# * unless, it will remain the same.

# %%
# df['age'] = df.Founded.apply(lambda x: x if int(x)<1 else 2021-x)

# %% [markdown]
# ### Type of Ownership

# %%
df['Type of ownership']=df['Type of ownership'].apply(lambda x:'Other Organization' if 'unknown' in x.lower() else('Other Organization' if x=='-1' else x))

# %%
df['Type of ownership'].value_counts()
# Out:
# Company - Private                 397
# Company - Public                  153
# Nonprofit Organization             36
# Other Organization                 36
# Subsidiary or Business Segment     28
# Government                         10
# Private Practice / Firm             4
# College / University                3
# Self-employed                       2
# Contract                            2
# Hospital                            1
# Name: Type of ownership, dtype: int64

# %% [markdown]
# ### Industry

# %%
df['Industry']=df['Industry'].apply(lambda x:'Other Industries' if x=='-1' else x)

# %%
df['Industry'].value_counts()
# Out:
# Other Industries                            71
# Biotech & Pharmaceuticals                   66
# IT Services                                 61
# Computer Hardware & Software                57
# Aerospace & Defense                         46
# Enterprise Software & Network Solutions     43
# Consulting                                  38
# Staffing & Outsourcing                      36
# Insurance Carriers                          28
# Internet                                    27
# Advertising & Marketing                     23
# Health Care Services & Hospitals            21
# Research & Development                      17
# Federal Agencies                            16
# Investment Banking & Asset Management       13
# Banks & Credit Unions                        8
# Lending                                      8
# Energy                                       5
# Consumer Products Manufacturing              5
# Telecommunications Services                  5
# ...

# %% [markdown]
# ### Sector

# %%
df['Sector']=df['Sector'].apply(lambda x:'Other Sectors' if x=='-1' else x)

# %%
df['Sector'].value_counts()
# Out:
# Information Technology                188
# Business Services                     120
# Other Sectors                          71
# Biotech & Pharmaceuticals              66
# Aerospace & Defense                    46
# Finance                                33
# Insurance                              32
# Manufacturing                          23
# Health Care                            21
# Government                             17
# Oil, Gas, Energy & Utilities           10
# Retail                                  7
# Telecommunications                      7
# Transportation & Logistics              6
# Media                                   5
# Real Estate                             3
# Travel & Tourism                        3
# Agriculture & Forestry                  3
# Education                               3
# Accounting & Legal                      3
# Construction, Repair & Maintenance      2
# Consumer Services                       2
# ...

# %% [markdown]
# ### Revenue

# %%
df['Revenue']=df['Revenue'].apply(lambda x:'Unknown / Non-Applicable' if x=='-1' else x)

# %%
df['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            240
# $100 to $500 million (USD)           94
# $10+ billion (USD)                   63
# $2 to $5 billion (USD)               45
# $10 to $25 million (USD)             41
# $1 to $2 billion (USD)               36
# $25 to $50 million (USD)             36
# $50 to $100 million (USD)            31
# $1 to $5 million (USD)               31
# $500 million to $1 billion (USD)     19
# $5 to $10 million (USD)              14
# Less than $1 million (USD)           14
# $5 to $10 billion (USD)               8
# Name: Revenue, dtype: int64

# %% [markdown]
# ### Competitors

# %%
len(df[df['Competitors']=='-1'])/len(df)
# Out:
# 0.7455357142857143

# %% [markdown]
# * 74% of data has mentioned unknown values as competitors.
# * we cannot remove the data, instead we rename it to "Others'.

# %%
df['Competitors']=df['Competitors'].apply(lambda x:'Others' if x=='-1' else x)

# %%
df_clean=df
df_clean.to_csv('Cleaned_DS_jobs.csv',index=False)

# %% [markdown]
# ## After Cleaning

# %%
cleaned_df=pd.read_csv('Cleaned_DS_jobs.csv')

# %%
cleaned_df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist     $137K-$171K
# 1     Data Scientist     $137K-$171K
# 2     Data Scientist     $137K-$171K
# 3     Data Scientist     $137K-$171K
# 4     Data Scientist     $137K-$171K
#
#                                      Job Description             Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst\n3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech\n4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group\n3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON\n3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions\n2.9
#
#         Location            Headquarters           Size Founded  \
# 0   New York, NY            New York, NY   1001 - 5000     1993
# 1  Chantilly, VA             Herndon, VA  5001 - 10000     1968
# 2     Boston, MA              Boston, MA   1001 - 5000     1981
# ...

# %% [markdown]
# Cleaned data contains 🧹 🧹
# 1. Job Title : contains title of the job
# 2. Salary Estimate: salary range of position
# 3. Job Description
# 4. Company Name
# 5. Location : location of job
# 6. Headquarters
# 7. Size : number of employees in the company
# 8. Founded : year the company was founded
# 9. Type of Ownership
# 10. Industry
# 11. Sector
# 12. Revenue
# 13. Competitors
# 14. min_salary
# 15. max_salary
# 16. avg_salary
# 17. skills coluumns: whether the position requires these skills or not
# 18. Company Name text : name of the company
# 19. Rating
# 20. Job location : state at which company is located
# 21. same_state: whether job locationa nd headquarters share the same place.
# 22. job_titles_simply : simple title of the job
# 23. seniority_by_title: seniority of job position

# %%
cleaned_df.shape
# Out:
# (672, 56)

# %%
cleaned_df.isnull().sum()
# Out:
# Job Title             0
# Salary Estimate       0
# Job Description       0
# Company Name          0
# Location              0
# Headquarters          0
# Size                  0
# Founded               0
# Type of ownership     0
# Industry              0
# Sector                0
# Revenue               0
# Competitors           0
# job_titles_simply     0
# seniority_by_title    0
# min_salary            0
# max_salary            0
# avg_salary            0
# python_yn             0
# R_yn                  0
# spark_yn              0
# aws_yn                0
# excel_yn              0
# sql_yn                0
# sas_yn                0
# d3js_yn               0
# julia_yn              0
# jupyter_yn            0
# keras_yn              0
# matlab_yn             0
# matplotlib_yn         0
# pytorch_yn            0
# scikit_yn             0
# tensor_yn             0
# weka_yn               0
# selenium_yn           0
# hadoop_yn             0
# tableau_yn            0
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Number of jobs in different titles

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,8))
plt.title("Count of different job titles",fontsize=20)

ax=sns.countplot(x='job_titles_simply',data=cleaned_df,order=df['job_titles_simply'].value_counts().index)
for label in ax.containers:
  ax.bar_label(label)

plt.ylabel("Number of job positions",fontsize=20)
plt.xlabel("Job titles",fontsize=20)
plt.show()

# %% [markdown]
# ### Spread of job locations in the USA

# %%
vals=df['Job_location'].value_counts()

# %%
locations_usa=vals.index

# %%
import plotly.express as px
fig=px.choropleth(cleaned_df,locations=locations_usa,locationmode='USA-states',scope='usa',color=vals,color_continuous_scale="Viridis_r")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.layout.coloraxis.colorbar.title = 'Job positions'

# %%
fig.update_layout(
      title_text = 'Distribution of Job openings in different states of USA',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black", 
      title_x=0.45, 
         )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def jobs_by_location():
  import plotly.express as px
  fig=px.choropleth(cleaned_df,locations=locations_usa,locationmode='USA-states',scope='usa',color=vals,color_continuous_scale="Viridis_r")
  fig.layout.coloraxis.colorbar.title = 'Job positions'
  fig.update_layout(
      title_text = 'Distribution of Job openings in different states of USA',
      title_font_family="Times New Roman",
      title_font_size = 22,
      title_font_color="black", 
      title_x=0.45, 
         )
  fig.show()

# %%
def jobs_by_location_graph():
  ax=sns.barplot(x=df["Job_location"].value_counts().index[0:10], y = df["Job_location"].value_counts()[0:10])
  for p in ax.patches:
      ax.text(p.get_x() + 0.1, p.get_height()+4.5, '{:.2f}%'.format((p.get_height()/672)*100))
  plt.show()

# %% [markdown]
# ### Rating of Companies

# %%
cleaned_df['Rating'].value_counts()
# Out:
# 3.5                         59
# 4.0                         42
# 3.3                         41
# 3.9                         40
# 3.8                         39
#                             ..
# 2.2                          1
# 2.3                          1
# Radical Convergence          1
# Covid-19 Search Partners     1
# AccessHope                   1
# Name: Rating, Length: 61, dtype: int64

# %%
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

# %%
cleaned_df['Rating']=cleaned_df['Rating'].apply(lambda x:float(x) if is_float(x) else 1)

# %%
def rating_distribution():
  plt.figure(figsize=(8,5))
  sns.distplot(cleaned_df['Rating'],kde=True,color='orange')
  plt.title("Distribution of Rating column")
  plt.show()

# %%
rating_distribution()

# %% [markdown]
# ### Jobs by Industries

# %%
Industries=cleaned_df['Industry'].value_counts()[0:15]

# %%
Industry_names=Industries.index

# %%
Industry_names
# Out:
# Index(['Other Industries', 'Biotech & Pharmaceuticals', 'IT Services',
#        'Computer Hardware & Software', 'Aerospace & Defense',
#        'Enterprise Software & Network Solutions', 'Consulting',
#        'Staffing & Outsourcing', 'Insurance Carriers', 'Internet',
#        'Advertising & Marketing', 'Health Care Services & Hospitals',
#        'Research & Development', 'Federal Agencies',
#        'Investment Banking & Asset Management'],
#       dtype='object')

# %%
def jobs_by_industries():
  plt.figure(figsize=(35,8))
  sns.barplot(x=Industry_names,y=Industries,data=cleaned_df)
  plt.title("Opening of Job positions by Industries",fontsize=20)
  plt.xlabel("Industries",fontsize=20)
  plt.ylabel("Count",fontsize=20)

# %%
jobs_by_industries()

# %% [markdown]
# ### Minimum Salary

# %%
sns.histplot(data=cleaned_df,x='min_salary')
plt.title("Range of minimum salaries",fontsize=20)
plt.show()

# %% [markdown]
# ### Maximum Salary

# %%
sns.histplot(data=cleaned_df,x='max_salary')
plt.title("Range of maximum salaries",fontsize=20)
plt.show()

# %% [markdown]
# ### Revenue

# %%
plt.figure(figsize=(40,8))
g = sns.countplot(x='Revenue', data=cleaned_df, order = df['Revenue'].value_counts().index)

# %% [markdown]
# ### Job description

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =1200, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Problems to be Answered

# %% [markdown]
# ###  **Identify the top 5 industries with highest number of openings**

# %%
jobs_by_industries()

# %% [markdown]
# 1. Other Industries
# 2. Biotech & Pharmaceuticals
# 3. IT Services
# 4. Computer Hardware and Software
# 5. Aerospace and Defense
# 6. Software and Network

# %% [markdown]
# ###  **Analyze the distribution of job oppurtunities based on geographic regions**

# %%
jobs_by_location()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
jobs_by_location_graph()

# %% [markdown]
# ---
# Most job positions are California followed by  Virginia, Massachusetts, NewYork, Maryland
#
#
# ---

# %% [markdown]
# ### **Determine the min and max average salary range for different positions across the industries and how salary changes from region to region**

# %%
df['job_titles_simply'].value_counts()
# Out:
# data scientist               474
# analyst                       54
# data engineer                 46
# other scientist               45
# machine learning engineer     35
# data modeler                   5
# data analytics                 4
# manager                        4
# na                             3
# director                       2
# Name: job_titles_simply, dtype: int64

# %%
def avg_salary_by_position_industry(position):
  salary=['avg_salary']
  position=cleaned_df[cleaned_df["job_titles_simply"]==position].groupby("Industry")[salary].mean().sort_values("avg_salary",ascending=False)[0:10]
  plt.figure(figsize=(30,5))
  sns.barplot(x=position.index,y=position['avg_salary'])

# %%
avg_salary_by_position_industry("data scientist")

# %%
avg_salary_by_position_industry("analyst")

# %%
avg_salary_by_position_industry("data engineer")

# %%
avg_salary_by_position_industry("machine learning engineer")

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Job_location",y="avg_salary",data=cleaned_df,order=df['Job_location'].value_counts().index)
# Out:
# <Axes: xlabel='Job_location', ylabel='avg_salary'>

# %% [markdown]
# * mostly average salaries range from 100k dollars to 150k dollars for mot states.
# * Delaware state has highest average salary.

# %% [markdown]
# * taking top 4 job positions data scientist, analyst, data engineer, machine learning engineer, integrate them with industries
# * average salary is determined by taking minimum and maximum salary of the positions.
# * for "*data scientist*" **publishing, health, beauty and fitness, State and regional agencies, hotels, motels and resorts** industries have more positions.
# * for "*analyst*" role **consulting, banks and credit unions, biotech and pharmaceuticals, Computer hardware and software** have more positions.
# * for "*data engineer*" **Industrial Manufacturing, Federal Agencies, Aerospace and defence, Bank and Union Credits** have more positions.
# * for "*machine learning engineer*" **Research and Development, Enterprise Software and Network Solutions, IT Services** have more positions.

# %% [markdown]
# ###  **Determine the most-in demand skills across industries and highlight emerging skill trends**

# %%
data=cleaned_df[["job_titles_simply",'python_yn','R_yn','spark_yn','aws_yn','excel_yn','sql_yn','sas_yn','d3js_yn','julia_yn','jupyter_yn','keras_yn','matlab_yn',
        'matplotlib_yn','pytorch_yn','scikit_yn','tensor_yn','weka_yn','selenium_yn','hadoop_yn','tableau_yn','bi_yn','bigml_yn','rapidminer_yn','flink_yn','datarobot_yn',
        'hana_yn','mongo_yn','avg_salary']]

# %%
skills=['python_yn','R_yn','spark_yn','aws_yn','excel_yn','sql_yn','sas_yn','d3js_yn','julia_yn','jupyter_yn','keras_yn','matlab_yn',
        'matplotlib_yn','pytorch_yn','scikit_yn','tensor_yn','weka_yn','selenium_yn','hadoop_yn','tableau_yn','bi_yn','bigml_yn','rapidminer_yn','flink_yn','datarobot_yn',
        'hana_yn','mongo_yn']
for i in skills:
  a = pd.pivot_table(data, index = 'job_titles_simply', columns = i, values = 'avg_salary', aggfunc = ['mean','count']).rename(columns={"mean":"Avg Salary(K)"})
  print(a)
# Out:
#                           Avg Salary(K)             count
# python_yn                             0           1     0      1
# job_titles_simply
# analyst                      117.250000  115.383333  24.0   30.0
# data analytics               103.000000  101.666667   1.0    3.0
# data engineer                113.777778  113.270270   9.0   37.0
# data modeler                  98.500000  145.250000   3.0    2.0
# data scientist               123.955556  125.618490  90.0  384.0
# director                            NaN  130.750000   NaN    2.0
# machine learning engineer    113.125000  116.241935   4.0   31.0
# manager                      144.375000         NaN   4.0    NaN
# na                           123.750000  164.500000   2.0    1.0
# other scientist              120.904762  140.750000  21.0   24.0
#                           Avg Salary(K)              count
# R_yn                                  0           1      0      1
# job_titles_simply
# ...

# %% [markdown]
# ---
# Python
#
#
# We see that job positions in which python skill is mentioned in the job description are getting paid more.
# Also, Python skill is required in about 77%, 31%, 65% and 82% of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
# AWS
#
# We see that job positions in which AWS skill is mentioned are getting paid more.
# Also, this skill is required in about 25%, 9%, 50% and 27% of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
# Excel
#
# Surprisingle, less salary for job postings in which Excel skill is mentioned.
# Also, this skill is required in about 50%, 76%, 45% and 32% of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
# SQL
#
# Not much relation between the skill and the average annual salary for different job positions.
# Also, this skill is required in about 56%, 74%, 73% and 59% of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
#
# SAS
#
# Not much relation between the skill and the average annual salary for different job positions.
# Also, this skill is required in about 16%, 11%, 0% and NA of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
# Hadoop
#
#
#
# Not much relation between the skill and the average annual salary for different job positions.
# Also, this skill is required in about 19%, NA, 42% and 18% of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
# Tableau
#
#
# Not much relation between the skill and the average annual salary for different job positions.
# Also, this skill is required in about 24%, 39%, 0.1% and NA of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
#
# PowerBi
#
# Not much relation between the skill and the average annual salary for different job positions.
# Also, this skill is required in about 0.1%, 16%, 0% and NA of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
#
# ---
#
#
# MongoDB
#
# Not much relation between the skill and the average annual salary for different job positions.
# Also, this skill is required in about 0.06%, 0.02%, 0.1% and NA of the job postings for Data Scientist, Data Analyst, Data Engineer and ML Engineer job positions respectively.
#
#
# ---
#
#
#
# ---
#
#
#
# Spark, Keras, Pytorch, Scikit, Tensor, Flink
#
# In most of the job postings, these skills aren't mentioned.

# %% [markdown]
# ### **Academic education fosters critical thinking and problem-solving skills. Through research, analysis, and rigorous study, students learn to evaluate information, develop logical reasoning, and apply problem-solving techniques. These skills are valuable in navigating real-life challenges, making informed decisions, and contributing to innovation and progress. So find out academic qualifications preferred by companies and distribution of them**

# %%
pd.pivot_table(cleaned_df,index='job_titles_simply',columns="Degree",values='avg_salary',aggfunc=['mean','count']).rename(columns={"mean":"avg_salary"})
# Out:
#                            avg_salary                          count        \
# Degree                              M           P          na      M     P
# job_titles_simply
# analyst                    134.166667         NaN  115.156863    3.0   NaN
# data analytics                    NaN         NaN  102.000000    NaN   NaN
# data engineer              108.444444         NaN  114.567568    9.0   NaN
# data modeler               145.250000         NaN   98.500000    2.0   NaN
# data scientist             122.892361  124.480000  126.905882  144.0  75.0
# director                          NaN  130.750000         NaN    NaN   2.0
# machine learning engineer  102.375000  119.388889  115.192308    4.0  18.0
# manager                           NaN  271.500000  102.000000    NaN   1.0
# na                                NaN  148.000000  132.000000    NaN   1.0
# other scientist            125.642857  135.333333  133.000000   14.0  15.0
#
#
# Degree                        na
# ...

# %% [markdown]
#  **Analyze the spread of the various companies ratings**

# %%
rating_distribution()

# %% [markdown]
# Most of the companies are rated between 3.5 - 4 (~3.7).

# %% [markdown]
#  **Analyze the distribution of the ownership of companies**

# %%
cleaned_df['Type of ownership'].value_counts()
# Out:
# Company - Private                 397
# Company - Public                  153
# Nonprofit Organization             36
# Other Organization                 36
# Subsidiary or Business Segment     28
# Government                         10
# Private Practice / Firm             4
# College / University                3
# Self-employed                       2
# Contract                            2
# Hospital                            1
# Name: Type of ownership, dtype: int64

# %%
plt.figure(figsize=(25,8))
plt.title("spread of companies among different ownerships",fontsize=20)

ax=sns.countplot(x='Type of ownership',data=cleaned_df ,order=df['Type of ownership'].value_counts().index)
for label in ax.containers:
  ax.bar_label(label)

plt.ylabel("Count of each ownerhip",fontsize=20)
plt.xlabel("Types of ownerships",fontsize=20)
plt.show()

# %% [markdown]
# ### **INSIGHTS**
#
#
# ---
#
# 1. Average lower salary is about $75K pa. We see 75% of the jobs positing has minimum salary =< than $91K pa, so it doesn't look like the mean value is affected much by the outlier( $15K or \$202K pa).
#
# 2. Average maximum salary is around $128K pa. We see 75% of the jobs positing has maximum salary =< than \$155K pa, so it doesn't look like the mean value is affected much by the outlier($16K or \$306K pa).
#
# 3. Mean Avg. salary is about $101K pa.
#
# 4. Most of the companies are rated between 3.5 - 4 (~3.7).
#
# 5. 37 unique states are present in the whole dataset, that's why we see 37 markers on the map.
#
# 6. Also, we see more point on the boundary of the country map becauise more people live in the coastal areas as compared to rest of the US.
#
# 7. California has the most number of jobs.
#
# 8. It is obvious for California to have most number of jobs as it is a hub for Tech. companies and has silicon valley.
#
# 9. Calfornia, Massachusetts, New York, Virginia together has around 50% jobs.
# 10. One surprising thing is, despite having the largest number of Fortune 500 companies HQ in New York, it is still on 3rd position. later we noticed that it is because of low salary job titles job postings in this state.
#
# 11. State with highest number of job, California also offers the highest average maximal annual salary, followed by Illinois.
#
# 12. Both California and Illinois has almost the same average minimal annual salary.
# 13. Pennsylvania has the lowest average minimum annual salary among the top 10 states.
# 14. Washington has the lowest average maximum annual salary among the top 10 states.
# 15. California has the highest average annual salary, followed by Illinois.
# 16.  This could be beacuse there are 74 job postings in California for Data scientists which are highly paid (shown later).
# 17. Maryland has the lowest average annual salary because it is hiring less number of people and the jobs are also distributed among high salary and low salary job titles.
# 18. Average Salary of California is twice the average salary of Alabama, Delaware, South Carolina, Idaho, Louisiana and Nebraska.
# 19. California has the highest average annual salary among all 10 states, followed by Illinois.
# 20. Pennsylvania, Texas and Washington has almost the same annual average salary.
# 21. Only 3 out of 10 states, California, Massachusetts and Illinois, have average annual salary more than $100K.
# 22. Overlap of 6/10 states between top 10 states reporting highest annual average salary and top 10 states where job postings are maximum.
# 23. Biotech & Pharmaceuticals Industry has maximum number of jobs followed by Insurance carriers.
# 24. As a surprise, IT industry has fewer jobs for data science related roles.
# More than 65% data science related jobs lie in top 10 industries.
# 25. For this dataset, Biotech & Pharmaceuticals Industry has twice the amount of jobs compared to IT services industry.
# 26. It looks like Heath Care Services & Hospitals industry is hiring at a good rate because they almost surpassed the IT services industry.
# 27. Computer Hardware & Software Industry has the highest average maximal salary among the 5 selected industries, it is followed by Biotech & Pharmaceuticals.
# 28. Computer Hardware & Software Industry also has the highest average minimal salary among the 5 selected industries, it is followed by Biotech & Pharmaceuticals.
# 29. Health Care Services & Hospitals industry has the lowest average maximal and minimal salary among the 5 selected industries.
# 30. Telecommunications Manufacturing Industry has the lowest average minimum and maximum salary among all the industries.
# 31. Financial Analytics & Research industry has the highest average minimum salary among all the industries.
# 32. Motion Picture Production & Distribution industry has the highest average maximum salary among all the industries.
# 33. In the previous plot, we also saw that a Pharmaceutical Industry was leading with the most number of job postings, we see the same trend here in this findings too. The industry also offered the highest minimum and maximum annual salary. It clearly shows that the demand of data science experts in this industry is increasing.
# 34. Again, we see that a Pharmaceuticals Company offers the highest minimal and maximal annual salary.
# * California -
#
#   Greentech has the highest minimal and maximal annual salary among top 5 companies with highest no. of job postings. It is followed by Central California Alliance for Health.
#
# * Massachusetts -
#   Takeda Pharmaceuticals has the highest maximal annual salary. It is followed by Novaritis.
#   Kronos Bi has the highest minimal annual salary, followed by Takeda Pharmaceuticals.
#
# * New York -
#   AstraZeneca has the highest maximal annual salary. It if followed by Rochester Regional Health.
#   Swiss Re has the highest minimal annual salary, followed by AstraZeneca.
#
# * Virginia -
#   Novetta has the highest maximal and minimal annual salary. -Illinois
#   Liberty Mutual Insurance has the highest maximal and minimal annual salary, followed by TransUnion.
#
# Ofcourse, companies with the largest number of employees offers high salary. There are more than 120 such companies in the data set.

# %% [markdown]
# 1. company size between 51-200 offers almost the same salary as the largest company. There are less than 120 such companies in the data set.
# 2. Not surprisingly, companies having less than 50 employee offers the third best salary. These are usally startups.
# 3. There are less number of such startups in the dataset.
# 4. Even though companies having 501-5000 employees are most common (more than 250 companies) in the dataset but they offer the least amount of salary.
# 5. Suprising companies having revenue between 5-10 Million pays more salary, followed by companies with revenue between 100 Million and companies with revenue more than 10 Billion.
# 6.  there are about 20 companies with revenue between 5 and 10 Million. There are around 17% companies that are older than 100 years and make revenue of $10+ billion.
